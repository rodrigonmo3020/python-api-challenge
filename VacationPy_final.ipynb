# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0            port-aux-francais -49.3500   70.2167      4.52
# 1        1                blackmans bay -43.0167  147.3167      7.07
# 2        2                  west island -12.1568   96.8225     25.99
# 3        3                         mana   5.6592  -53.7767     28.04
# 4        4  edinburgh of the seven seas -37.0676  -12.3116     10.43
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        88         100        2.79      TF  1698268459
# 1        74          98        1.34      AU  1698268459
# 2        83          40        6.69      CC  1698268459
# 3        76          98        5.83      GF  1698268460
# 4        56          16        6.17      SH  1698268460

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE#
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 500,
    size = "Humidity",
    scale = 1,
    color = "City"
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE

vacation_city_data_df = city_data_df.loc[city_data_df['Max Temp'] <=25, ['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed', 'Country', 'Date']]

vacation_city_data_df = vacation_city_data_df.loc[city_data_df['Max Temp'] >=20, ['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed', 'Country', 'Date']]

vacation_city_data_df = vacation_city_data_df.loc[city_data_df['Wind Speed'] <4.5, ['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed', 'Country', 'Date']]

vacation_city_data_df = vacation_city_data_df.loc[city_data_df['Cloudiness'] <50, ['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed', 'Country', 'Date']]

vacation_city_data_df
# Out:
#                             City      Lat       Lng  Max Temp  Humidity  \
# 22                       al jawf  29.5000   38.7500     23.66        38
# 110   san sebastian de la gomera  28.0916  -17.1133     23.54        73
# 111                     windhoek -22.5594   17.0832     24.19        20
# 146                       putian  25.4394  119.0103     20.52        87
# 173                 saint-pierre -21.3393   55.4781     24.76        73
# 184                       janeng -25.4167   25.5500     20.80         9
# 195                      konarka  19.9000   86.1167     24.22        80
# 200                     imbituba -28.2400  -48.6703     21.06        78
# 218                        crane  31.3974 -102.3501     24.72        43
# 224                   federacion -31.0062  -57.8996     21.44        64
# 226                       songea -10.6833   35.6500     21.03        74
# 227                     tangalle   6.0240   80.7911     24.25        88
# ...

# %%
# Drop any rows with null values
# YOUR CODE HERE
vacation_city_data_df = vacation_city_data_df.dropna()
vacation_city_data_df.info()

# Display sample data
# YOUR CODE HERE
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 22 to 572
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        33 non-null     object
#  1   Lat         33 non-null     float64
#  2   Lng         33 non-null     float64
#  3   Max Temp    33 non-null     float64
#  4   Humidity    33 non-null     int64
#  5   Cloudiness  33 non-null     int64
#  6   Wind Speed  33 non-null     float64
#  7   Country     33 non-null     object
#  8   Date        33 non-null     int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 2.6+ KB

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

hotel_df = vacation_city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()


# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df["Hotel name"] = ' ' 


# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                             City Country      Lat       Lng  Humidity  \
# 22                       al jawf      SA  29.5000   38.7500        38
# 110   san sebastian de la gomera      ES  28.0916  -17.1133        73
# 146                       putian      CN  25.4394  119.0103        87
# 173                 saint-pierre      RE -21.3393   55.4781        73
# 184                       janeng      BW -25.4167   25.5500         9
# 195                      konarka      IN  19.9000   86.1167        80
# 200                     imbituba      BR -28.2400  -48.6703        78
# 218                        crane      US  31.3974 -102.3501        43
# 224                   federacion      AR -31.0062  -57.8996        64
# 226                       songea      TZ -10.6833   35.6500        74
# 227                     tangalle      LK   6.0240   80.7911        88
# 231                     westport      US  41.1415  -73.3579        65
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    # YOUR CODE HERE
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key

}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}" # YOUR CODE HERE
    params["bias"] = f"proximity:{longitude},{latitude}" # YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params) # YOUR CODE HERE
    
    # Convert the API response to JSON format
    name_address = name_address.json() # YOUR CODE HERE
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# C:\Users\rodri\AppData\Local\Temp\ipykernel_36420\1298236950.py:39: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'No hotel found' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   hotel_df.loc[index, "Hotel Name"] = "No hotel found"
# al jawf - nearest hotel: No hotel found
# san sebastian de la gomera - nearest hotel: Hotel Villa Gomera
# putian - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# janeng - nearest hotel: No hotel found
# konarka - nearest hotel: Hotel Sun Village
# imbituba - nearest hotel: Silvestre Praia Hotel
# crane - nearest hotel: No hotel found
# federacion - nearest hotel: Arena Resort
# songea - nearest hotel: No hotel found
# tangalle - nearest hotel: Coco Tangalla
# westport - nearest hotel: Norwalk Inn and Conference Center
# mahanoro - nearest hotel: Vanilla Bungalow
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE

hotel_map = hotel_df.hvplot.points(
    "Lng", "Lat", 
    geo = True, 
    color = "City",
    alpha = 0.8,
    size = "Humidity",
    tiles = "OSM",
    frame_width = 800,
    frame_height = 500,
    hover_cols = ["Hotel Name", "Country"]
                                  )

# Display the map
# YOUR CODE HERE
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
